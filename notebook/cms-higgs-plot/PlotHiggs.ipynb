# %%
# %matplotlib widget

# %%
import json
import matplotlib.pyplot as plt
import plotting.plotnb as plotnb

# %%
figure = plotnb.setup_figure()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
plotnb.reset_data()
while True:
    data   = plotnb.load_data()
    groups = plotnb.update_plot(figure,data)
